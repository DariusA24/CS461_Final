# %%
import torch
import pathlib
import random
import math
import numpy as np
import torch.utils.data as tdata
import torch.optim as opt
import torch.nn as nn
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision.utils import make_grid
from sklearn.metrics import roc_curve, auc
from tqdm.notebook import tqdm
import torch.utils.data as data
import matplotlib.pyplot as plt

# %%
n_epochs = 2
batch_size_train = 8
batch_size_test = 8
learning_rate = 0.001
logging_interval = 1
validation_percent = 0.2
Training_Path =  ("/Users/dariusargueta/Desktop/CS_461/Final/data/train")
Testing_Path =  ("/Users/dariusargueta/Desktop/CS_461/Final/data/test")

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)), #Values are means and SD 
    #transforms.RandomSizedCrop(224),
    transforms.RandomHorizontalFlip(),
    # transforms.   Resize(size=128, interpolation=PIL.Image.BILINEAR)
    transforms.Resize(size=128),
    transforms.CenterCrop(size=(128,128))
   
])

#download the data
tr_dataset = torchvision.datasets.ImageFolder(root=Training_Path, transform=transform)

# %%
tr_idxs = list(range(len(tr_dataset)))
split = math.floor(len(tr_dataset)*validation_percent)
dataset_size = len(tr_dataset)
indicies = list(range(dataset_size))

# %%
train_data_loader = data.DataLoader(tr_dataset, batch_size=batch_size_train, sampler=SubsetRandomSampler(tr_idxs[split:]))
valid_data_loader = tdata.DataLoader(tr_dataset, batch_size=batch_size_test, sampler=SubsetRandomSampler(tr_idxs[split:]))

# %%
te_data = torchvision.datasets.ImageFolder(root=Testing_Path, transform=transform)
test_data_loader  = data.DataLoader(te_data, batch_size=batch_size_test, shuffle=True)

# %%
classes=tr_dataset.classes
print(classes)
# Out:
# ['benign', 'malignant']

# %%
from PIL import Image
img = Image.open                                                       \
(r"/Users/dariusargueta/Desktop/CS_461/Final/data/train/benign/100.jpg")
img = transform(img)
print(img.size())
# Out:
# torch.Size([3, 128, 128])

# %% [markdown]
# Have to switch this code up

# %%
def imshow(imgs, title):
  imgs=imgs.cpu()
  mean=torch.tensor([0.485,0.456,0.406]).view(1,3,1,1)
  std=torch.tensor([0.229,0.224,0.225]).view(1,3,1,1)
  imgs=imgs*std+mean
  img_grid=make_grid(imgs,nrow=4)
  img_np=img_grid.numpy()
  img_np=np.transpose(img_np,(1,2,0))
  plt.figure(figsize=(8,4))
  plt.imshow(img_np)
  plt.title(title)
  plt.show()

# %% [markdown]
# Have to switch this code up

# %%
for i,batch in enumerate(test_data_loader):
  if i==4:
    break
  imgs,labels=batch
  imshow(imgs,str([classes[i] for i in labels]))

# %%
#Getting the number of training examples:
num_train =  (len(tr_dataset))

#Number of testing examples:
num_test = (len(te_data))

#Number of validation examples:
num_val = len(valid_data_loader.dataset)
# #Shape of our image:
# image_shape = train_data_loader[0].shape
# print(image_shape)

#Num of classes:
num_classes = len(np.unique(tr_dataset.classes))

print("Number of training examples: ", num_train)
print("Number of testing examples: ", num_test)
print("Number of validation examples: ", num_val)

print("Number of classes: ", num_classes)
# Out:
# Number of training examples:  2637
# Number of testing examples:  660
# Number of validation examples:  2637
# Number of classes:  2

# %%
Operational_device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
#Creating a Multinomial Logistic Regression Classifier
class NeuralNetwork(nn.Module):
  def __init__(self, n_in, n_out):
    #Always use the super
    super(NeuralNetwork, self).__init__()
    # self.fc1 = nn.Linear(12288*12288, 32)
    # self.fc2 = nn.Linear(32, 64)
    # self.fc3 = nn.Linear(64,1)
    # self.flatten = nn.Flatten()
    # self.linear_relu_stack = nn.Sequential(
    #   nn.Linear(12288*12288, 32),
    #   nn.ReLU(),
    #   nn.Linear(32,32),
    #   nn.ReLU(),
    #   nn.Linear(32,1)
    # )
    self.linear = nn.Linear(n_in, n_out)

  def forward(self, x):
    # x = torch.FloatTensor(x)
    # x = self.flatten(x)
    # print("X: ", x)
    # # x = torch.FloatTensor(x)
    # logits = self.linear_relu_stack(x)
    # return logits
    #return self.linear(x) #w @ x + b
    # print("X: ", x)
    # x = torch.relu(self.fc1(x))
    # x = torch.relu(self.fc2(x))
    # x = torch.sigmoid(self.fc3(x), return_dict=False)
    # return x 
    return self.linear(x)

# %%
model = NeuralNetwork(49152,2).to(Operational_device)
lossfn = nn.CrossEntropyLoss(reduction='mean')
optimizer = opt.SGD(model.parameters(), lr=learning_rate)

# %%
# X = torch.rand(1,28,28)
# logits = model(X)
# pred_probab = nn.Softmax(dim=1)(logits)
# y_pred = pred_probab.argmax(1)
# print(f"Predicted class: {y_pred}")
# Out:
# tensor([[[[2.0576, 2.1224, 2.2630,  ..., 1.5938, 1.8987, 1.5823],
#           [2.1316, 2.1684, 2.3535,  ..., 2.0516, 2.0363, 2.0087],
#           [2.1636, 2.1809, 2.2783,  ..., 2.0725, 2.1157, 2.1576],
#           ...,
#           [1.6861, 1.8597, 1.8708,  ..., 2.0423, 2.0673, 2.0532],
#           [1.6401, 1.7748, 1.8736,  ..., 2.2107, 2.1871, 2.1632],
#           [1.7302, 1.7772, 1.8384,  ..., 2.1260, 1.9882, 2.0419]],
#
#          [[1.5845, 1.6734, 1.7374,  ..., 1.4506, 1.7193, 1.4232],
#           [1.6923, 1.7054, 1.8502,  ..., 1.8496, 1.8426, 1.8156],
#           [1.7758, 1.7318, 1.8084,  ..., 1.8802, 1.9025, 1.9562],
#           ...,
#           [1.3416, 1.4520, 1.4506,  ..., 1.7402, 1.7485, 1.7770],
#           [1.3277, 1.3838, 1.4409,  ..., 1.8237, 1.8613, 1.8424],
#           [1.3856, 1.4627, 1.4683,  ..., 1.8307, 1.7096, 1.7513]],
#
#          [[1.5990, 1.7018, 1.7867,  ..., 1.3583, 1.7273, 1.4186],
#           [1.7732, 1.7579, 1.9472,  ..., 1.8589, 1.9076, 1.8639],
#           [1.8985, 1.7829, 1.8943,  ..., 1.9216, 1.9995, 2.0087],
#           ...,
#           [1.2143, 1.2895, 1.3717,  ..., 1.6728, 1.7730, 1.7784],
#           [1.2199, 1.2394, 1.3118,  ..., 1.7827, 1.8148, 1.8675],
#           [1.2730, 1.3559, 1.3323,  ..., 1.7929, 1.6899, 1.7364]]],
#
#
#         [[[2.3495, 2.3330, 2.3832,  ..., 2.2533, 2.2213, 2.2268],
#           [2.3472, 2.3122, 2.3456,  ..., 2.2764, 2.2471, 2.1817],
#           [2.2943, 2.3149, 2.2704,  ..., 2.3237, 2.3334, 2.2708],
#           ...,
#           [1.9751, 1.9444, 2.0795,  ..., 2.0819, 2.0638, 2.0395],
#           [1.9973, 1.9138, 2.0878,  ..., 2.0735, 2.0457, 2.0562],
#           [2.0196, 1.9218, 2.0443,  ..., 2.0878, 2.0795, 2.0162]],
#
#          [[1.1601, 1.1143, 1.1992,  ..., 1.0409, 1.0409, 1.0089],
#           [1.1636, 1.0962, 1.1268,  ..., 1.0956, 1.0775, 1.0610],
#           [1.1595, 1.1603, 1.0544,  ..., 1.1624, 1.1541, 1.1153],
#           ...,
#           [0.8074, 0.7768, 0.9480,  ..., 0.9667, 0.9751, 0.9894],
#           [0.8228, 0.7476, 0.9773,  ..., 0.9862, 0.9459, 1.0187],
#           [0.8973, 0.8043, 0.9727,  ..., 1.0280, 1.0350, 1.0012]],
#
#          [[1.1799, 1.1439, 1.2692,  ..., 1.1503, 1.1851, 1.1145],
#           [1.2112, 1.1171, 1.1477,  ..., 1.2263, 1.2235, 1.1368],
#           [1.1541, 1.1630, 1.0962,  ..., 1.3474, 1.3738, 1.2301],
#           ...,
#           [0.7086, 0.6430, 0.8462,  ..., 0.9594, 0.9622, 0.9510],
#           [0.7364, 0.5956, 0.8866,  ..., 1.0248, 1.0081, 1.0304],
#           [0.7683, 0.6656, 0.8397,  ..., 1.0461, 1.0002, 0.9560]]],
#
#
#         [[[1.0606, 1.0202, 1.0453,  ..., 1.1412, 1.0883, 1.0381],
#           [1.1002, 1.0712, 1.0572,  ..., 1.0988, 1.1016, 1.1266],
#           [1.0793, 1.0920, 1.0391,  ..., 1.1308, 1.0459, 1.1280],
#           ...,
#           [1.0423, 1.0157, 1.0366,  ..., 1.1360, 1.0385, 1.0075],
#           [1.0256, 1.0574, 1.0588,  ..., 1.1513, 0.9564, 0.9477],
#           [0.9892, 1.0067, 1.0680,  ..., 1.1396, 0.8862, 0.8534]],
#
#          [[0.8727, 0.8363, 0.8544,  ..., 0.9490, 0.8878, 0.8884],
#           [0.8949, 0.8393, 0.8615,  ..., 0.8910, 0.8854, 0.9809],
#           [0.8741, 0.8407, 0.8337,  ..., 0.9272, 0.8534, 0.9419],
#           ...,
#           [0.8526, 0.8078, 0.8357,  ..., 0.9546, 0.8669, 0.7838],
#           [0.8359, 0.8232, 0.8802,  ..., 0.9365, 0.7416, 0.6724],
#           [0.8170, 0.8444, 0.8918,  ..., 0.9302, 0.6698, 0.5575]],
#
#          [[0.8285, 0.7981, 0.8162,  ..., 1.0292, 0.9582, 0.9393],
#           [0.8456, 0.8379, 0.8253,  ..., 0.9333, 0.9570, 1.0286],
#           [0.8387, 0.8323, 0.8393,  ..., 0.9654, 0.8916, 0.9785],
#           ...,
#           [0.8595, 0.8442, 0.8359,  ..., 1.1169, 1.0000, 0.9353],
#           [0.8512, 0.8679, 0.8693,  ..., 1.0654, 0.8705, 0.8560],
#           [0.8170, 0.8444, 0.8918,  ..., 1.0574, 0.7971, 0.7211]]],
#
#
#         ...,
#
#
#         [[[2.1435, 2.1666, 2.1819,  ..., 2.1795, 2.1865, 2.2075],
#           [2.1908, 2.1956, 2.2151,  ..., 2.2451, 2.2632, 2.1718],
#           [2.1895, 2.2151, 2.2346,  ..., 2.2646, 2.2048, 2.2121],
#           ...,
#           [2.1055, 2.1596, 2.1596,  ..., 2.0793, 2.2296, 2.2636],
#           [2.1487, 2.1721, 2.1624,  ..., 2.0292, 2.2185, 2.2678],
#           [2.1391, 2.1642, 2.1531,  ..., 2.0200, 2.2121, 2.2624]],
#
#          [[1.9574, 1.9597, 1.9444,  ..., 1.9333, 1.9430, 1.9329],
#           [1.9951, 1.9830, 1.9621,  ..., 2.0132, 2.0216, 1.9299],
#           [1.9757, 1.9733, 1.9816,  ..., 2.0550, 1.9757, 1.9814],
#           ...,
#           [1.9273, 1.9784, 1.9687,  ..., 1.8341, 2.1167, 2.1067],
#           [1.9593, 1.9812, 1.9812,  ..., 1.7505, 2.0721, 2.0705],
#           [1.9542, 1.9902, 1.9749,  ..., 1.7014, 2.0494, 2.0256]],
#
#          [[1.5278, 1.5238, 1.4904,  ..., 1.4582, 1.4387, 1.4347],
#           [1.5751, 1.5546, 1.5198,  ..., 1.5532, 1.5198, 1.4208],
#           [1.5890, 1.5644, 1.5588,  ..., 1.5964, 1.4948, 1.4946],
#           ...,
#           [1.4679, 1.5393, 1.5518,  ..., 1.3846, 1.6143, 1.7525],
#           [1.5361, 1.5839, 1.6061,  ..., 1.3345, 1.4960, 1.7149],
#           [1.5407, 1.6085, 1.6197,  ..., 1.3472, 1.4112, 1.6724]]],
#
#
#         [[[2.4440, 2.4953, 2.5204,  ..., 2.4786, 2.3895, 2.4538],
#           [2.4587, 2.4983, 2.4886,  ..., 2.4283, 2.4227, 2.4571],
#           [2.4406, 2.4635, 2.4343,  ..., 2.3963, 2.4687, 2.3834],
#           ...,
#           [2.2408, 2.2068, 2.2652,  ..., 2.1107, 2.1469, 2.1344],
#           [2.2658, 2.2429, 2.2040,  ..., 2.0286, 2.1037, 2.1427],
#           [2.2159, 2.2328, 2.2342,  ..., 2.0723, 2.0821, 2.1135]],
#
#          [[1.3687, 1.4287, 1.4468,  ..., 1.3277, 1.2734, 1.3563],
#           [1.3822, 1.4319, 1.4291,  ..., 1.2086, 1.3158, 1.3579],
#           [1.3683, 1.4319, 1.4486,  ..., 1.2476, 1.3840, 1.3148],
#           ...,
#           [1.3136, 1.2748, 1.3388,  ..., 1.1109, 1.1945, 1.1817],
#           [1.3428, 1.3138, 1.2609,  ..., 1.0149, 1.1666, 1.1692],
#           [1.3176, 1.3017, 1.2682,  ..., 1.0385, 1.0831, 1.1499]],
#
#          [[1.7774, 1.8350, 1.8392,  ..., 1.8114, 1.7404, 1.7772],
#           [1.7845, 1.8478, 1.8130,  ..., 1.7436, 1.7631, 1.7957],
#           [1.7581, 1.8394, 1.7949,  ..., 1.7283, 1.7867, 1.7288],
#           ...,
#           [1.5421, 1.4958, 1.5765,  ..., 1.3927, 1.4637, 1.4433],
#           [1.5449, 1.5333, 1.5069,  ..., 1.3635, 1.4150, 1.4377],
#           [1.5170, 1.5361, 1.5306,  ..., 1.4055, 1.3832, 1.4172]]],
#
#
#         [[[1.6384, 1.7782, 2.0288,  ..., 1.8569, 1.9070, 1.8866],
#           [1.5839, 1.6107, 1.5815,  ..., 1.6616, 1.5155, 1.4978],
#           [1.6855, 1.5439, 1.7875,  ..., 1.7674, 1.8064, 1.7316],
#           ...,
#           [1.7410, 1.8436, 1.5819,  ..., 1.9305, 1.7426, 1.9502],
#           [1.8579, 1.7169, 1.8450,  ..., 1.9806, 1.7245, 1.9168],
#           [1.6043, 1.5819, 1.9160,  ..., 1.7889, 1.6483, 1.8752]],
#
#          [[1.1085, 1.2563, 1.5083,  ..., 1.3223, 1.4059, 1.3902],
#           [1.0668, 1.1241, 1.0851,  ..., 1.1270, 1.0143, 1.0033],
#           [1.2269, 1.0698, 1.3134,  ..., 1.2328, 1.3052, 1.2511],
#           ...,
#           [1.2859, 1.3886, 1.1268,  ..., 1.4643, 1.2764, 1.5049],
#           [1.4474, 1.3064, 1.4345,  ..., 1.5242, 1.2583, 1.4506],
#           [1.2030, 1.2000, 1.5411,  ..., 1.3112, 1.1567, 1.3756]],
#
#          [[0.8186, 1.0049, 1.2973,  ..., 1.1187, 1.1911, 1.1738],
#           [0.8138, 0.8882, 0.8910,  ..., 0.9234, 0.8023, 0.8114],
#           [0.9976, 0.8645, 1.1109,  ..., 1.0320, 1.1155, 1.0523],
#           ...,
#           [1.1109, 1.2136, 0.9518,  ..., 1.3482, 1.1714, 1.3945],
#           [1.3058, 1.1648, 1.2929,  ..., 1.3788, 1.1435, 1.3361],
#           [1.0660, 1.0727, 1.4277,  ..., 1.1229, 0.9836, 1.2277]]]])

# %%
for e in range(n_epochs): #goes over the entire dataset at each iteration 
  model.train() #track gradients 
  tr_loss = 0
  # training step 
  for idx, batch in enumerate(train_data_loader, 0): #iterating over mini-batches
      optimizer.zero_grad()
      outputs = model(batch[0].view(-1,49152)) # [0] will get the input x from the mini batch
      loss = lossfn(outputs, batch[1]) # [1] will get the output y from the mini-batch
      loss.backward() #calcualtes gradients
      optimizer.step() #performs gradient descent update 
      tr_loss += loss.item()
  #Validation step
  model.eval() #no need to track gradients
  with torch.no_grad():
    val_loss = 0
    for idx, batch in enumerate(valid_data_loader, 0):
      outputs = model(batch[0].view(-1,49152))
      loss = lossfn(outputs, batch[1])
      val_loss += loss.item()
  
  #print some stats:
  if e % logging_interval == 0:
    print(f'Epoch: {e} TrLoss: {tr_loss/len(train_data_loader.sampler)} . ValLoss: {val_loss/len(valid_data_loader.sampler)}')
# Out:
# Epoch: 0 TrLoss: 0.11082365384316557 . ValLoss: 0.08582726474409985
# Epoch: 1 TrLoss: 0.09872621839504106 . ValLoss: 0.14854615832109586

# %% [markdown]
# class MLR(nn.Module):
#   def __init__(self, n_in, n_out):
#     #Always use the super
#     super(MLR, self).__init__()
#     self.linear = nn.Linear(n_in, n_out)
#
#   def forward(self, x):
#     # x = self.linear1(x)
#     # x = nn.ReLu(x)
#     # x = self.linear2(x)
#     # x = nn.ReLu(x)
#     # x = self.linear3(x)
#     return self.linear(x) #w @ x + b

# %% [markdown]
# model = MLR(784, 10)
# lossfn = nn.CrossEntropyLoss(reduction='mean')
# optimizer = opt.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
#  for e in range(n_epochs): #goes over the entire dataset at each iteration
#   model.train() #track gradients
#   tr_loss = 0
#   # training step
#   for idx, batch in enumerate(train_data, 0): #iterating over mini-batches
#       optimizer.zero_grad()
#       outputs = model(batch[0].view(-1,784)) # [0] will get the input x from the mini batch
#       loss = lossfn(outputs, batch[1]) # [1] will get the output y from the mini-batch
#       loss.backward() #calcualtes gradients
#       optimizer.step() #performs gradient descent update
#       tr_loss += loss.item()
#   #Validation step
#   model.eval() #no need to track gradients
#   with torch.no_grad():
#     val_loss = 0
#     for idx, batch in enumerate(valid_data, 0):
#       outputs = model(batch[0].view(-1,784))
#       loss = lossfn(outputs, batch[1])
#       val_loss += loss.item()
#
#   #print some stats:
#   if e % logging_interval == 0:
#     print(f'Epoch: {e} TrLoss: {tr_loss/len(train_data.sampler)} . ValLoss: {val_loss/len(valid_data.sampler)}')
